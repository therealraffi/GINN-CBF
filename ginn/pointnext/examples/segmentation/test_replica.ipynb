# %%
import os
import time
import glob
import yaml
import argparse
import logging
import pathlib
from pathlib import Path
import struct
import warnings
from random import randint
import json

import numpy as np
import torch
from tqdm import tqdm
from scipy.spatial import ConvexHull, Delaunay, cKDTree, KDTree
from sklearn.neighbors import NearestNeighbors
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

import open3d as o3d
import trimesh
import k3d
import wandb

from plyfile import PlyData

from concurrent.futures import ThreadPoolExecutor

warnings.simplefilter(action='ignore', category=FutureWarning)
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
import json
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from plyfile import PlyData
from pathlib import Path
from collections import defaultdict
from tqdm import tqdm
import k3d
import trimesh
import random

# === Paths ===
data_root = "/scratch/rhm4nj/cral/datasets/Replica-Dataset/ReplicaSDK"
room_name = "office_4"
room_path = Path(data_root) / room_name
segment_floor = True

def rgb_to_uint(rgb):
    r, g, b = rgb
    return (int(r) << 16) + (int(g) << 8) + int(b)

def calculate_bounds(points):
    x_min, x_max = np.min(points[:, 0]), np.max(points[:, 0])
    y_min, y_max = np.min(points[:, 1]), np.max(points[:, 1])
    z_min, z_max = np.min(points[:, 2]), np.max(points[:, 2])
    return np.array([[x_min, x_max], [y_min, y_max], [z_min, z_max]]), (np.array([x_min, y_min, z_min]), np.array([x_max, y_max, z_max]))

def get_upper_xy_plane_points(point_cloud, bbox_min, bbox_max, z_tol=1e-3):
    z_max = bbox_max[2]
    return np.abs(point_cloud[:, 2] - z_max) < z_tol

def get_lower_xy_plane_points(point_cloud, bbox_min, bbox_max, z_tol=1e-3):
    z_min = bbox_min[2]
    return np.abs(point_cloud[:, 2] - z_min) < z_tol

def downsample_random_indices(points, K):
    indices = np.random.choice(points.shape[0], K, replace=False)
    return indices

# %%
# === Load semantic metadata ===
ply_path = room_path / "habitat" / "mesh_semantic.ply"
info_path = room_path / "habitat" / "info_semantic.json"

with open(info_path, "r") as f:
    info = json.load(f)

class_mapping = {}
for ele in info["classes"]:
    class_mapping[ele["id"]] = ele["name"]
for ele in info["objects"]:
    class_mapping[ele["id"]] = ele["class_name"]

# === Load mesh ===
plydata = PlyData.read(str(ply_path))
vertex_array = np.stack([
    plydata['vertex']['x'],
    plydata['vertex']['y'],
    plydata['vertex']['z']
], axis=-1)

face_data = plydata['face'].data
face_indices = [f[0] for f in face_data]
object_ids = np.array([f[1] for f in face_data], dtype=np.uint16)

# Assign vertex labels
vertex_object_ids = np.zeros(vertex_array.shape[0], dtype=np.uint16)
used = np.zeros(vertex_array.shape[0], dtype=bool)
for face, oid in zip(face_indices, object_ids):
    for v in face:
        if not used[v]:
            vertex_object_ids[v] = oid
            used[v] = True

# %%
room_points = vertex_array  # treat entire mesh as room

_, (bbox_min, bbox_max) = calculate_bounds(room_points)

# Identify ceiling and floor
ceiling_mask = get_upper_xy_plane_points(room_points, bbox_min, bbox_max, z_tol=0.45)
exclude_mask = ceiling_mask

if segment_floor:
    floor_mask = get_lower_xy_plane_points(room_points, bbox_min, bbox_max, z_tol=1e-1)
    exclude_mask = ceiling_mask | floor_mask

# Exclude those points by index
excluded_indices = np.where(exclude_mask)[0]
excluded_index_set = set(excluded_indices.tolist())

print(f"Excluding {len(excluded_index_set)} vertices")
excluded_points = room_points[exclude_mask]

# # Create a plot
# plot = k3d.plot()
# plot += k3d.points(
#     positions=room_points[~exclude_mask],
#     point_size=0.01,
#     color=0xff0000,  # red for excluded
#     name="all points"
# )
# plot += k3d.points(
#     positions=room_points[ceiling_mask].astype(np.float32),
#     point_size=0.01,
#     color=0x0000ff,  # blue = ceiling
#     name="ceiling"
# )

# if segment_floor:
#     plot += k3d.points(
#         positions=room_points[floor_mask].astype(np.float32),
#         point_size=0.01,
#         color=0x00ff00,  # green = floor
#         name="floor"
#     )

# plot.display()
# Out:
# Excluding 457397 vertices

# %%
from sklearn.cluster import DBSCAN

MIN_POINTS = 40  # filter threshold
all_fragments = []

if segment_floor:
    eps = 0.05
else:
    eps = 0.15

oid_to_faces = defaultdict(list)
for face, oid in zip(face_indices, object_ids):
    oid_to_faces[oid].append(face)

for oid, faces in tqdm(oid_to_faces.items(), desc="Extracting object fragments"):    
    valid_faces = []
    for face in faces:
        if all(v in excluded_index_set for v in face):
            continue  # skip face on ceiling or floor
        valid_faces.append(face)

    if not valid_faces:
        continue

    faces = np.array(valid_faces)

    unique_vertex_indices, inverse_indices = np.unique(faces.flatten(), return_inverse=True)
    local_vertices = vertex_array[unique_vertex_indices]
    local_faces = inverse_indices.reshape(faces.shape)

    db = DBSCAN(eps=eps, min_samples=5).fit(local_vertices)
    labels = db.labels_

    num_clusters = len(set(labels)) - (1 if -1 in labels else 0)
    class_name = class_mapping.get(oid, f"unknown_{oid}")

    for cluster_id in range(num_clusters):
        mask = (labels == cluster_id)
        num_pts = mask.sum()

        if num_pts < MIN_POINTS:
            continue

        cluster_points = local_vertices[mask]
        all_fragments.append({
            "points": cluster_points,
            "centroid": cluster_points.mean(axis=0),
            "oid": oid,
            "class_name": class_name,
            "num_points": num_pts
        })
# Out:
# Extracting object fragments: 100%|██████████| 71/71 [00:05<00:00, 12.44it/s]

# %%
# === Print 5 smallest fragments ===
sorted_frags = sorted(all_fragments, key=lambda f: f["num_points"])
print("5 smallest fragments (after filtering):")
for frag in sorted_frags[:10]:
    print(f"- Class: {frag['class_name']}, Points: {frag['num_points']}")
# Out:
# 5 smallest fragments (after filtering):
# - Class: anonymize_text, Points: 40
# - Class: anonymize_text, Points: 42
# - Class: chair, Points: 58
# - Class: wall-plug, Points: 60
# - Class: wall-plug, Points: 69
# - Class: anonymize_picture, Points: 69
# - Class: wall-plug, Points: 100
# - Class: undefined, Points: 117
# - Class: undefined, Points: 131
# - Class: panel, Points: 141

# %%
from scipy.spatial import KDTree, cKDTree
import networkx as nx
from scipy.spatial.distance import cdist

# Precompute bounding boxes
bbox_centers = []
bbox_extents = []
for frag in all_fragments:
    pts = frag["points"]
    bounds = np.stack([pts.min(axis=0), pts.max(axis=0)])
    center = bounds.mean(axis=0)
    extent = bounds[1] - bounds[0]
    bbox_centers.append(center)
    bbox_extents.append(extent)

bbox_centers = np.stack(bbox_centers)
bbox_extents = np.stack(bbox_extents)

# Build KDTree over bounding box centers
tree = KDTree(bbox_centers)
touch_threshold = 0.02
G = nx.Graph()
G.add_nodes_from(range(len(all_fragments)))

print("Building contact graph (fast)...")

for i in tqdm(range(len(all_fragments))):
    # Search neighbors within radius (center distance + extent fudge factor)
    extent_radius = np.linalg.norm(bbox_extents[i]) / 2 + 1.0  # generous margin
    neighbors = tree.query_ball_point(bbox_centers[i], r=extent_radius)

    pi = all_fragments[i]["points"]
    pi_tree = cKDTree(pi)

    for j in neighbors:
        if j <= i:
            continue

        pj = all_fragments[j]["points"]
        dists, _ = pi_tree.query(pj, k=1)
        if np.any(dists < touch_threshold):
            G.add_edge(i, j)
            # print("Connecting edges", all_fragments[i]['class_name'], all_fragments[j]['class_name'], dists[dists < touch_threshold].min())

components = list(nx.connected_components(G))
super_clusters = []

for i, component in enumerate(components):
    component = list(component)
    fragment_names = [f"{all_fragments[idx]['class_name']}_frag{idx}" for idx in component]
    fragment_sizes = [all_fragments[idx]['points'].shape[0] for idx in component]

    # Find largest fragment
    largest_idx = component[np.argmax(fragment_sizes)]
    key_name = f"{all_fragments[largest_idx]['class_name']}"

    # Concatenate all points in the component
    merged_points = np.vstack([all_fragments[idx]["points"] for idx in component])
    super_clusters.append((key_name, merged_points))

room_points = vertex_array  # assuming this is the full mesh still
super_clusters.append(("ceiling", room_points[ceiling_mask]))

if segment_floor:
    super_clusters.append(("floor", room_points[floor_mask]))

print(f"Found {len(super_clusters)} superclusters")
# Out:
# Building contact graph (fast)...
#   0%|          | 0/54 [00:00<?, ?it/s]
# 100%|██████████| 54/54 [00:32<00:00,  1.66it/s]
# Found 10 superclusters

# %%
plot = k3d.plot()
color_map = {key: random.randint(0, 0xFFFFFF) for key in range(len(super_clusters))}

for i, (key, component) in enumerate(super_clusters):
    plot += k3d.points(
        positions=component.astype(np.float32),
        point_size=0.01,
        color=color_map[i],
        name=key
    )

plot.display()

print([(key, component.shape) for key, component in super_clusters])
# Out:
# Output()
# [('non-plane', (449257, 3)), ('chair', (1086, 3)), ('chair', (951, 3)), ('chair', (17521, 3)), ('chair', (974, 3)), ('window', (56428, 3)), ('table', (3075, 3)), ('chair', (17387, 3)), ('ceiling', (248517, 3)), ('floor', (208880, 3))]

# %%
def average_nearest_neighbor_distance(points):
    tree = cKDTree(points)
    distances, _ = tree.query(points, k=2)
    nn_distances = distances[:, 1]
    return np.mean(nn_distances), np.std(nn_distances)

def remove_outliers(point_cloud, method="statistical", nb_neighbors=25, std_ratio=1.5, radius=0.1, min_neighbors=5, ret_indices=False):
    # Convert to Open3D point cloud
    pcd = o3d.geometry.PointCloud()
    pcd.points = o3d.utility.Vector3dVector(point_cloud)

    if method == "statistical":
        # Statistical Outlier Removal (SOR)
        clean_pcd, inlier_indices = pcd.remove_statistical_outlier(nb_neighbors=nb_neighbors, std_ratio=std_ratio)
    elif method == "radius":
        # Radius Outlier Removal (ROR)
        clean_pcd, inlier_indices = pcd.remove_radius_outlier(nb_points=min_neighbors, radius=radius)
    else:
        raise ValueError("Invalid method. Use 'statistical' or 'radius'.")

    if ret_indices:
        return np.asarray(clean_pcd.points), np.asarray(inlier_indices)

    return np.asarray(clean_pcd.points)

def filtered_point_cloud_indices(A, B, min_distance=0.1, tree=None, ret_dist=False):
    if tree is None:
        tree = cKDTree(A)
    distances, _ = tree.query(B)
    if ret_dist:
        return distances > min_distance, distances[distances > min_distance]
    
    return distances > min_distance

def sample_states_and_controls_timed(inner_point_cloud, point_cloud, N, K, min_dot=0.25):
    def sample_vector():
        vec = np.random.randn(3)
        return vec / np.linalg.norm(vec)

    idx = np.random.choice(point_cloud.shape[0], N, replace=False)
    sampled_points = point_cloud[idx]
    kdtree = cKDTree(inner_point_cloud)
    distances, nearest_indices = kdtree.query(sampled_points, k=2)
    nearest_neighbors = inner_point_cloud[nearest_indices[:, 1]]
    sampled_data = []

    for i in range(N):
        x, y, z = sampled_points[i]
        uc = nearest_neighbors[i] - sampled_points[i]
        uc = uc / np.linalg.norm(uc)
        sampled_data.append([x, y, z, uc[0], uc[1], uc[2]])
        for _ in range(K - 1):
            random_vector = sample_vector()
            while np.dot(random_vector, uc) < min_dot:
                random_vector = -random_vector
                if np.dot(random_vector, uc) < min_dot:
                    random_vector = sample_vector()
            sampled_data.append([x, y, z, random_vector[0], random_vector[1], random_vector[2]])

    return np.array(sampled_data)

def compute_interface_normals(interface_filtered, normal_radius, max_nn):
    pcd = o3d.geometry.PointCloud()
    pcd.points = o3d.utility.Vector3dVector(interface_filtered)
    pcd.estimate_normals(
        search_param=o3d.geometry.KDTreeSearchParamHybrid(radius=normal_radius, max_nn=max_nn)
    )
    pcd.normalize_normals()
    normals = np.asarray(pcd.normals)
    print("Interface / Normals", interface_filtered.shape, normals.shape)
    return normals

def compute_pts_on_env(domain_filtered, all_outers_filtered, interface_density, pts_on_env_thickness):
    ao_env = all_outers_filtered[
        filtered_point_cloud_indices(domain_filtered, all_outers_filtered, interface_density)
    ]
    pts_on_env = ao_env[
        ~filtered_point_cloud_indices(domain_filtered, ao_env, pts_on_env_thickness)
    ]
    print("Done with pts_on_env", pts_on_env.shape)
    return pts_on_env

def compute_outer_points(domain_filtered, all_outers_filtered, outer_density):
    outers = all_outers_filtered[
        filtered_point_cloud_indices(domain_filtered, all_outers_filtered, outer_density)
    ]
    print("Done with outers/envelope", outers.shape)
    return outers

from sklearn.decomposition import PCA

def compute_oriented_bbox(points, margin=0.0):
    center = points.mean(axis=0)
    centered = points - center

    pca = PCA(n_components=3)
    pca.fit(centered)
    rotation = pca.components_.T  # each column is an axis

    rotated = centered @ rotation
    min_corner = rotated.min(axis=0) - margin
    max_corner = rotated.max(axis=0) + margin

    # Get 8 corners in PCA space
    corners_pca = np.array([
        [min_corner[0], min_corner[1], min_corner[2]],
        [max_corner[0], min_corner[1], min_corner[2]],
        [max_corner[0], max_corner[1], min_corner[2]],
        [min_corner[0], max_corner[1], min_corner[2]],
        [min_corner[0], min_corner[1], max_corner[2]],
        [max_corner[0], min_corner[1], max_corner[2]],
        [max_corner[0], max_corner[1], max_corner[2]],
        [min_corner[0], max_corner[1], max_corner[2]],
    ])

    # Transform corners back to world space
    corners_world = (corners_pca @ rotation.T) + center
    return corners_world

def sample_inside_oriented_bbox(corners, num_points=1000):
    origin = corners[0]
    edge_x = corners[1] - corners[0]  # along x
    edge_y = corners[3] - corners[0]  # along y
    edge_z = corners[4] - corners[0]  # along z
    u = np.random.uniform(0, 1, (num_points, 1))
    v = np.random.uniform(0, 1, (num_points, 1))
    w = np.random.uniform(0, 1, (num_points, 1))
    samples = origin + u * edge_x + v * edge_y + w * edge_z
    return samples

# %%
augemented_points = []
class_pts = super_clusters

def thicken_point_cloud_outward(points, num_augmented=3, noise_scale=0.01):
    N, _ = points.shape
    centroid = points.mean(axis=0)
    expanded_points = [points]  # include original
    for _ in range(num_augmented):
        # Direction from centroid to each point
        directions = points - centroid
        directions = directions / (np.linalg.norm(directions, axis=1, keepdims=True) + 1e-6)

        # Apply directional noise
        noise = directions * (np.random.rand(N, 1) * noise_scale)
        new_points = points + noise
        expanded_points.append(new_points)

    return np.vstack(expanded_points)


for cname, points in class_pts:
    print(cname, points.shape)
    # if cname != 'floor': continue
    indices = downsample_random_indices(points, min(points.shape[0], 300_000))
    points = np.ascontiguousarray(points, dtype=np.float64)
    points = points[indices]

    # tighter
    interface_thickness=0.035
    pts_on_env_thickness = 0.06
    pts_on_env_gap = 0.075
    inner_thickness=0.06
    normal_radius=0.025
    max_nn=30
    rad = 0.03
    inner_density_factor = 1.25

    # interface_thickness=0.025
    # pts_on_env_thickness = 0.05
    # pts_on_env_gap = 0.075
    # inner_thickness=0.05
    # normal_radius=0.025
    # max_nn=30
    # inner_density_factor = 3

    pcd = o3d.geometry.PointCloud()
    pcd.points = o3d.utility.Vector3dVector(points)
    pcd.estimate_normals(
        search_param=o3d.geometry.KDTreeSearchParamHybrid(radius=normal_radius, max_nn=max_nn)
    )
    pcd.normalize_normals()
    normals = np.asarray(pcd.normals)

    inners = []
    for step in np.linspace(1e-3, inner_thickness, 5):
        inners.append(points + normals * step)
        inners.append(points - normals * step)

    domain = np.vstack(inners)  # And the opposite direction
    inner_m, inner_std = average_nearest_neighbor_distance(domain)
    inner_density = inner_m + inner_std * inner_density_factor + rad

    min_neighbors = 8

    # inner layer
    domain_filtered = domain[downsample_random_indices(domain, min(points.shape[0] * 5, 400_000))]
    domain_filtered = remove_outliers(domain_filtered, radius=inner_density, min_neighbors=min_neighbors)
    inner_m, inner_std = average_nearest_neighbor_distance(domain_filtered)
    inner_density = inner_m + inner_std * inner_density_factor + rad
    print("inner_density", inner_density)
    print("Done with inner layer", domain_filtered.shape)

    # all points
    bbox_offset = 0.25
    n_all_outers = min(points.shape[0] * 10, 1_000_000)
    _, bounds_box = calculate_bounds(domain_filtered)
    expanded_bounds = bounds_box[0] - bbox_offset, bounds_box[1] + bbox_offset
    all_outers = np.random.uniform(low=expanded_bounds[0], high=expanded_bounds[1], size=(n_all_outers, 3))

    domain_tree = cKDTree(domain_filtered)
    all_outers_filtered = all_outers[
        filtered_point_cloud_indices(domain_filtered, all_outers, inner_density, tree=domain_tree)
    ]
    print("Done with all points", all_outers_filtered.shape)

    # interface
    interface_thickness = inner_density + interface_thickness
    # interface_inp = thicken_point_cloud_outward(domain_filtered, 10, noise_scale=0.75)
    # interface_inp = interface_inp[downsample_random_indices(interface_inp, min(interface_inp.shape[0] * 5, 400_000))]
    interface_filtered = all_outers_filtered[
        ~filtered_point_cloud_indices(domain_filtered, all_outers_filtered, interface_thickness)
    ]
    print("Done with interface", interface_filtered.shape)

    # Prepare variables for parallel work
    interface_density = interface_thickness
    pts_on_env_thickness = interface_density + pts_on_env_thickness
    outer_density = pts_on_env_thickness + inner_density
    
    # Normals
    pcd = o3d.geometry.PointCloud()
    pcd.points = o3d.utility.Vector3dVector(interface_filtered)
    pcd.estimate_normals(
        search_param=o3d.geometry.KDTreeSearchParamHybrid(radius=normal_radius, max_nn=max_nn)
    )
    pcd.normalize_normals()
    normals_filtered = np.asarray(pcd.normals)
    print("Interface / Normals", interface_filtered.shape, normals_filtered.shape)

    interface_tree = cKDTree(interface_filtered)
    # pts_on_env
    ao_env = all_outers_filtered[
        filtered_point_cloud_indices(domain_filtered, all_outers_filtered, interface_density + pts_on_env_gap)
    ]
    pts_on_env_filtered = ao_env[
        ~filtered_point_cloud_indices(domain_filtered, ao_env, pts_on_env_thickness + pts_on_env_gap)
    ]
    pts_on_env_filtered_dists, _ = interface_tree.query(pts_on_env_filtered)
    print("Done with pts_on_env", pts_on_env_filtered.shape, pts_on_env_filtered_dists.shape)

    # envelope_filtered
    envelope_filtered = all_outers_filtered[
        filtered_point_cloud_indices(domain_filtered, all_outers_filtered, outer_density)
    ]
    envelope_filtered_dists, _ = interface_tree.query(envelope_filtered)
    print("Done with outers/envelope", envelope_filtered.shape, envelope_filtered_dists.shape)

    # control
    N = min(100_000, domain_filtered.shape[0] // 10)
    K = 30
    control_outs_env = sample_states_and_controls_timed(domain_filtered, envelope_filtered, N // 3, K)
    control_outs_on_env = sample_states_and_controls_timed(domain_filtered, pts_on_env_filtered, N // 3, K)
    control_outs_interface = sample_states_and_controls_timed(domain_filtered, interface_filtered, N // 3, K)
    control_outs = np.vstack([control_outs_env, control_outs_interface, control_outs_on_env])
    control_points, controls = control_outs[:, :3], control_outs[:, 3:]
    print("Done with control", control_points.shape)

    # bounds, scaling, translation
    all_points = np.vstack([domain, interface_filtered, pts_on_env_filtered, envelope_filtered])
    bounds_og, bounds_coords = calculate_bounds(all_points)
    bbox_min, bbox_max = bounds_coords
    bounds = bounds_og.copy()

    all_points_obj = np.vstack([domain, interface_filtered])
    bounds_obj, _ = calculate_bounds(all_points_obj)

    center_for_translation = (bbox_max + bbox_min) / 2
    scale_factor = max(bbox_max - bbox_min) / 2

    print("Done with bounds, scaling, translation:", bounds_coords, scale_factor, center_for_translation)

    augemented_points.append({
        "class": cname,
        "pts_inside": domain_filtered,
        "env_outside_pts": envelope_filtered,
        "pts_on_env": pts_on_env_filtered,
        "pts_on_env_dists": pts_on_env_filtered_dists,
        "env_outside_pts_dists": envelope_filtered_dists,
        "outside_points_dists": envelope_filtered_dists,
        "outside_points": envelope_filtered,
        "control_points": control_outs,
        "control_points_on_env": control_outs_on_env,
        "control_points_env": control_outs_env,
        "control_points_interface": control_outs_interface,
        "original": points,
        "interface_pts": interface_filtered,
        "interface_normals": normals_filtered,
        "bounds": bounds,
        "bounds_obj": bounds_obj,
        "scale_factor": scale_factor,
        "center_for_translation": center_for_translation
    })
# Out:
# non-plane (449257, 3)
# inner_density 0.052954905459986754
# Done with inner layer (370918, 3)
# Done with all points (905955, 3)
# Done with interface (37363, 3)
# Interface / Normals (37363, 3) (37363, 3)
# Done with pts_on_env (64585, 3) (64585,)
# Done with outers/envelope (750464, 3) (750464,)
# Done with control (1112670, 3)
# Done with bounds, scaling, translation: (array([-1.50681646, -2.6343341 , -1.40997365]), array([5.6320011 , 4.48924136, 1.43516471])) 3.569408782370381 [2.06259232 0.92745363 0.01259553]
# chair (1086, 3)
# inner_density 0.04320203687821303
# Done with inner layer (4924, 3)
# Done with all points (10391, 3)
# Done with interface (420, 3)
# Interface / Normals (420, 3) (420, 3)
# Done with pts_on_env (1609, 3) (1609,)
# Done with outers/envelope (7889, 3) (7889,)
# Done with control (14760, 3)
# Done with bounds, scaling, translation: (array([ 2.44602614, -1.98190746, -1.41843309]), array([ 3.52302062, -0.81761141, -0.66972862])) 0.5821480225453667 [ 2.98452338 -1.39975943 -1.04408086]
# chair (951, 3)
# inner_density 0.04306689524505353
# Done with inner layer (4355, 3)
# Done with all points (9088, 3)
# Done with interface (426, 3)
# Interface / Normals (426, 3) (426, 3)
# Done with pts_on_env (1516, 3) (1516,)
# Done with outers/envelope (6665, 3) (6665,)
# Done with control (13050, 3)
# Done with bounds, scaling, translation: (array([ 1.09551281, -2.02179192, -1.41886261]), array([ 2.05671755, -0.84022697, -0.65485759])) 0.590782472847242 [ 1.57611518 -1.43100944 -1.0368601 ]
# chair (17521, 3)
# inner_density 0.04497859243122306
# Done with inner layer (81809, 3)
# Done with all points (154277, 3)
# Done with interface (7174, 3)
# Interface / Normals (7174, 3) (7174, 3)
# Done with pts_on_env (16856, 3) (16856,)
# Done with outers/envelope (121741, 3) (121741,)
# Done with control (245340, 3)
# Done with bounds, scaling, translation: (array([-0.73585114, -2.51085045, -1.39144823]), array([ 0.96168416, -0.81552711,  0.03562923])) 0.848767649501563 [ 0.11291651 -1.66318878 -0.6779095 ]
# chair (974, 3)
# inner_density 0.04291150146526303
# Done with inner layer (4468, 3)
# Done with all points (9309, 3)
# Done with interface (397, 3)
# Interface / Normals (397, 3) (397, 3)
# Done with pts_on_env (1464, 3) (1464,)
# Done with outers/envelope (6969, 3) (6969,)
# Done with control (13320, 3)
# Done with bounds, scaling, translation: (array([ 1.49438874,  0.90269221, -1.42502088]), array([ 2.59242685,  2.05827538, -0.71127915])) 0.5777915869421377 [ 2.0434078   1.4804838  -1.06815001]
# window (56428, 3)
# inner_density 0.04661374276044665
# Done with inner layer (262223, 3)
# Done with all points (484037, 3)
# Done with interface (32627, 3)
# Interface / Normals (32627, 3) (32627, 3)
# Done with pts_on_env (66452, 3) (66452,)
# Done with outers/envelope (342699, 3) (342699,)
# Done with control (786600, 3)
# Done with bounds, scaling, translation: (array([-1.37769936,  3.30281193, -1.38059483]), array([3.48569747, 4.41128648, 1.42249213])) 2.4316984160355597 [1.05399906 3.8570492  0.02094865]
# table (3075, 3)
# inner_density 0.04282068377434624
# Done with inner layer (14028, 3)
# Done with all points (28414, 3)
# Done with interface (1602, 3)
# Interface / Normals (1602, 3) (1602, 3)
# Done with pts_on_env (4767, 3) (4767,)
# Done with outers/envelope (20194, 3) (20194,)
# Done with control (42030, 3)
# Done with bounds, scaling, translation: (array([-0.88947064,  1.66164151, -1.3900178 ]), array([ 0.16181121,  2.70029145, -0.42111961])) 0.5256409264381926 [-0.36382972  2.18096648 -0.9055687 ]
# chair (17387, 3)
# inner_density 0.044873434458001904
# Done with inner layer (81104, 3)
# Done with all points (150943, 3)
# Done with interface (8184, 3)
# Interface / Normals (8184, 3) (8184, 3)
# Done with pts_on_env (18532, 3) (18532,)
# Done with outers/envelope (115045, 3) (115045,)
# Done with control (243270, 3)
# Done with bounds, scaling, translation: (array([-1.12051174,  2.19406705, -1.38896597]), array([ 5.39598789e-01,  3.78181830e+00, -3.73127090e-03])) 0.8300552649149576 [-0.29045648  2.98794267 -0.69634862]
# ceiling (248517, 3)
# inner_density 0.05016385484107391
# Done with inner layer (367800, 3)
# Done with all points (826045, 3)
# Done with interface (68904, 3)
# Interface / Normals (68904, 3) (68904, 3)
# Done with pts_on_env (120903, 3) (120903,)
# Done with outers/envelope (539771, 3) (539771,)
# Done with control (1103400, 3)
# Done with bounds, scaling, translation: (array([-1.49291044, -2.60839745,  0.88847958]), array([5.62281615, 4.47427202, 1.90460481])) 3.557863297383615 [2.06495286 0.93293729 1.3965422 ]
# floor (208880, 3)
# inner_density 0.04923432014859752
# Done with inner layer (371616, 3)
# Done with all points (793487, 3)
# Done with interface (81541, 3)
# Interface / Normals (81541, 3) (81541, 3)
# Done with pts_on_env (149670, 3) (149670,)
# Done with outers/envelope (449134, 3) (449134,)
# Done with control (1114830, 3)
# Done with bounds, scaling, translation: (array([-1.49631101, -2.60352116, -1.51927716]), array([ 5.6165765 ,  4.4638354 , -0.80468351])) 3.556443755199272 [ 2.06013275  0.93015712 -1.16198033]

# %%
import k3d
import numpy as np
import random

plot = k3d.plot()

colors = {
    # "original": 0xff0000,             # Red
    "pts_inside": 0x00ff00,           # Green
    "interface_pts": 0x0000ff,        # Blue
    # "env_outside_pts": 0xffff00,      # Yellow
    # "pts_on_env": 0xff00ff,           # Magenta
    # "outside_points": 0x00ffff,       # Cyan
    # "control_points": 0x808080,       # Gray
    # "control_points_on_env": 0x800080,# Orange 0xFFA500
    # "control_points_env": 0x800080,   # Purple
    # "control_points_interface": 0x008000 # Dark Green
}

# print(domain.shape, domain_normals.shape)
# # plot += k3d.vectors(domain[:domain_normals.shape[0]], domain_normals, color=0x0000ff, head_size=0.1)  # Blue
# print(interface_filtered.shape, normals_filtered.shape)
# plot += k3d.vectors(interface_filtered, normals_filtered / 10, color=0xFFA500, head_size=0.25, line_width=0.001)  # Blue
# plot += k3d.points(interface_tmp, point_size=0.01, color=0x808080)
# plot += k3d.points(pts_on_env_tmp, point_size=0.01, color=0x008000)

# plot += k3d.points(bounds_obj.T, point_size=0.05, color=0x008000)
plot.display()
for i, data_dict in enumerate(augemented_points):
    print(f"\nPlotting object {i}: {data_dict.get('class', 'Unknown')}")
    # if data_dict.get('class', 'Unknown') != 'wall':
        # continue
    
    for key, value in data_dict.items():
        if not isinstance(value, np.ndarray):
            continue
        
        if value.ndim == 2 and value.shape[1] >= 3:
            pts = value[:, :3]
            col = colors.get(key, -1)
            if col != -1:
                plot += k3d.points(pts, point_size=0.01, color=col)
                print(f"{key} bounds: min {pts.min(axis=0)}, max {pts.max(axis=0)}")
                print("ADDED", key, pts.shape)

# plot += k3d.points(interface_tmp_big, point_size=0.01, color=0x008000)
# Out:
# Output()
# Plotting object 0: non-plane
# pts_inside bounds: min [-1.25682534 -2.38435338 -1.159975  ], max [5.3820038  4.239247   1.18516791]
# ADDED pts_inside (370918, 3)
# interface_pts bounds: min [-1.33929137 -2.47179033 -1.23073242], max [5.4586391  4.31745441 1.26523386]
# ADDED interface_pts (37363, 3)
#
# Plotting object 1: chair
# pts_inside bounds: min [ 2.69571899 -1.73220663 -1.16855857], max [ 3.27312417 -1.06760806 -0.91970667]
# ADDED pts_inside (4924, 3)
# interface_pts bounds: min [ 2.62671504 -1.78654667 -1.23190325], max [ 3.34832507 -1.00240463 -0.85481554]
# ADDED interface_pts (420, 3)
#
# Plotting object 2: chair
# pts_inside bounds: min [ 1.34548256 -1.77180891 -1.16890698], max [ 1.80677072 -1.0899938  -0.90483083]
# ADDED pts_inside (4355, 3)
# interface_pts bounds: min [ 1.28477033 -1.82984036 -1.24093905], max [ 1.8665826  -1.02077972 -0.84060441]
# ADDED interface_pts (426, 3)
#
# Plotting object 3: chair
# pts_inside bounds: min [-0.48585172 -2.26085623 -1.14147633], max [ 0.71168435 -1.0655258  -0.21436366]
# ADDED pts_inside (81809, 3)
# interface_pts bounds: min [-0.56375245 -2.3372713  -1.20928932], max [ 0.78426244 -0.98902858 -0.13724073]
# ADDED interface_pts (7174, 3)
#
# Plotting object 4: chair
# pts_inside bounds: min [ 1.74418279  1.15233341 -1.17505967], max [ 2.34258972  1.80854601 -0.96124628]
# ADDED pts_inside (4468, 3)
# interface_pts bounds: min [ 1.70000421  1.08868052 -1.24987855], max [ 2.41142168  1.88059601 -0.90110476]
# ADDED interface_pts (397, 3)
#
# Plotting object 5: window
# pts_inside bounds: min [-1.12771495  3.55281096 -1.13060466], max [3.23570091 4.16128772 1.17249305]
# ADDED pts_inside (262223, 3)
# interface_pts bounds: min [-1.20816314  3.47522079 -1.20349194], max [3.30963899 4.24243179 1.25056245]
# ADDED interface_pts (32627, 3)
#
# Plotting object 6: table
# pts_inside bounds: min [-0.63947537  1.91162969 -1.14003995], max [-0.08817351  2.45029646 -0.67108214]
# ADDED pts_inside (14028, 3)
# interface_pts bounds: min [-0.7092495   1.83550518 -1.20809116], max [-0.02619152  2.52196093 -0.59522527]
# ADDED interface_pts (1602, 3)
#
# Plotting object 7: chair
# pts_inside bounds: min [-0.87051294  2.44405314 -1.1389769 ], max [ 0.2896086   3.53183885 -0.25373036]
# ADDED pts_inside (81104, 3)
# interface_pts bounds: min [-0.94308855  2.36887797 -1.21744119], max [ 0.360188    3.60891682 -0.17579245]
# ADDED interface_pts (8184, 3)
#
# Plotting object 8: ceiling
# /scratch/rhm4nj/.conda/final_ginn_env/lib/python3.11/site-packages/traittypes/traittypes.py:97: UserWarning: Given trait value dtype "float64" does not match required type "float32". A coerced copy has been created.
#   warnings.warn(
# pts_inside bounds: min [-1.24291052 -2.35840021  1.13847951], max [5.37282978 4.22427553 1.65460561]
# ADDED pts_inside (367800, 3)
# interface_pts bounds: min [-1.32069752 -2.43739263  1.06653001], max [5.45051604 4.30384439 1.73486823]
# ADDED interface_pts (68904, 3)
#
# Plotting object 9: floor
# pts_inside bounds: min [-1.2463333  -2.35354328 -1.26927735], max [ 5.36657725  4.21384929 -1.05468348]
# ADDED pts_inside (371616, 3)
# interface_pts bounds: min [-1.32672663 -2.42368589 -1.35137162], max [ 5.4430562   4.2901961  -0.98052334]
# ADDED interface_pts (81541, 3)

# %%
import k3d
from k3d.colormaps import matplotlib_color_maps
import numpy as np

# Step 1: Concatenate points and distances
env_pts_all = []
env_dists_all = []
int_all = []

for data_dict in augemented_points:
    if not isinstance(data_dict, dict):
        continue
    if not (data_dict.get('class', 'Unknown') == 'wall' or data_dict.get('class', 'Unknown') == 'wall'):
        continue

    env_pts = data_dict.get("env_outside_pts")
    env_dists = data_dict.get("env_outside_pts_dists")
    on_env_pts = data_dict.get("pts_on_env")
    on_env_dists = data_dict.get("pts_on_env_dists")
    interface = data_dict.get("interface_pts")

    if env_pts is not None and env_dists is not None and env_pts.shape[0] == env_dists.shape[0]:
        env_pts_all.append(env_pts)
        env_dists_all.append(env_dists)

    if on_env_pts is not None and on_env_dists is not None and on_env_pts.shape[0] == on_env_dists.shape[0]:
        env_pts_all.append(on_env_pts)
        env_dists_all.append(on_env_dists)
    
    int_all.append(interface)

# Step 2: Stack arrays
if env_pts_all and env_dists_all:
    all_pts = np.vstack(env_pts_all).astype(np.float32)
    all_dists = np.concatenate(env_dists_all).astype(np.float32)
    int_all = np.vstack(int_all).astype(np.float32)

    # Step 3: Create a separate plot
    env_plot = k3d.plot()
    env_plot += k3d.points(
        all_pts,
        attribute=all_dists,
        point_size=0.05,
        color_map=matplotlib_color_maps.Inferno
    )
    env_plot += k3d.points(int_all, point_size=0.05, color=0x0000ff)
    env_plot.display()
else:
    print("No envelope or on-env points found.")
# Out:
# No envelope or on-env points found.

# %%
import shutil

suffix = ""
if segment_floor:
    suffix = "_objects"
else:
    suffix = "_single"

name = room_name + suffix
out_path = os.path.join(
    "/scratch/rhm4nj/cral/cral-ginn/ginn/myvis/data_gen", 
    "replica",
    name
)
print("Saving to:", out_path)

if not os.path.exists(out_path):
    os.makedirs(out_path)
else:
    shutil.rmtree(out_path)

skips_names = []

for idx, values in enumerate(augemented_points):
    folder_name = f"{idx}_{values['class']}"
    folder_path = os.path.join(out_path, folder_name)
    os.makedirs(folder_path)

    for name, arrays in values.items():
        if name in skips_names: continue

        print(f'Saving to {folder_name}:', name)
        np.save(f'{folder_path}/{name}.npy', arrays)
# Out:
# Saving to: /scratch/rhm4nj/cral/cral-ginn/ginn/myvis/data_gen/replica/office_4_objects
# Saving to 0_non-plane: class
# Saving to 0_non-plane: pts_inside
# Saving to 0_non-plane: env_outside_pts
# Saving to 0_non-plane: pts_on_env
# Saving to 0_non-plane: pts_on_env_dists
# Saving to 0_non-plane: env_outside_pts_dists
# Saving to 0_non-plane: outside_points_dists
# Saving to 0_non-plane: outside_points
# Saving to 0_non-plane: control_points
# Saving to 0_non-plane: control_points_on_env
# Saving to 0_non-plane: control_points_env
# Saving to 0_non-plane: control_points_interface
# Saving to 0_non-plane: original
# Saving to 0_non-plane: interface_pts
# Saving to 0_non-plane: interface_normals
# Saving to 0_non-plane: bounds
# Saving to 0_non-plane: bounds_obj
# Saving to 0_non-plane: scale_factor
# Saving to 0_non-plane: center_for_translation
# Saving to 1_chair: class
# Saving to 1_chair: pts_inside
# Saving to 1_chair: env_outside_pts
# Saving to 1_chair: pts_on_env
# Saving to 1_chair: pts_on_env_dists
# Saving to 1_chair: env_outside_pts_dists
# Saving to 1_chair: outside_points_dists
# Saving to 1_chair: outside_points
# Saving to 1_chair: control_points
# Saving to 1_chair: control_points_on_env
# Saving to 1_chair: control_points_env
# Saving to 1_chair: control_points_interface
# Saving to 1_chair: original
# Saving to 1_chair: interface_pts
# Saving to 1_chair: interface_normals
# Saving to 1_chair: bounds
# Saving to 1_chair: bounds_obj
# Saving to 1_chair: scale_factor
# Saving to 1_chair: center_for_translation
# Saving to 2_chair: class
# Saving to 2_chair: pts_inside
# Saving to 2_chair: env_outside_pts
# Saving to 2_chair: pts_on_env
# Saving to 2_chair: pts_on_env_dists
# Saving to 2_chair: env_outside_pts_dists
# Saving to 2_chair: outside_points_dists
# Saving to 2_chair: outside_points
# Saving to 2_chair: control_points
# Saving to 2_chair: control_points_on_env
# Saving to 2_chair: control_points_env
# Saving to 2_chair: control_points_interface
# Saving to 2_chair: original
# Saving to 2_chair: interface_pts
# Saving to 2_chair: interface_normals
# Saving to 2_chair: bounds
# Saving to 2_chair: bounds_obj
# Saving to 2_chair: scale_factor
# Saving to 2_chair: center_for_translation
# Saving to 3_chair: class
# Saving to 3_chair: pts_inside
# Saving to 3_chair: env_outside_pts
# Saving to 3_chair: pts_on_env
# Saving to 3_chair: pts_on_env_dists
# Saving to 3_chair: env_outside_pts_dists
# Saving to 3_chair: outside_points_dists
# Saving to 3_chair: outside_points
# Saving to 3_chair: control_points
# Saving to 3_chair: control_points_on_env
# Saving to 3_chair: control_points_env
# Saving to 3_chair: control_points_interface
# Saving to 3_chair: original
# Saving to 3_chair: interface_pts
# Saving to 3_chair: interface_normals
# Saving to 3_chair: bounds
# Saving to 3_chair: bounds_obj
# Saving to 3_chair: scale_factor
# Saving to 3_chair: center_for_translation
# Saving to 4_chair: class
# Saving to 4_chair: pts_inside
# Saving to 4_chair: env_outside_pts
# Saving to 4_chair: pts_on_env
# Saving to 4_chair: pts_on_env_dists
# Saving to 4_chair: env_outside_pts_dists
# Saving to 4_chair: outside_points_dists
# Saving to 4_chair: outside_points
# Saving to 4_chair: control_points
# Saving to 4_chair: control_points_on_env
# Saving to 4_chair: control_points_env
# Saving to 4_chair: control_points_interface
# Saving to 4_chair: original
# Saving to 4_chair: interface_pts
# Saving to 4_chair: interface_normals
# Saving to 4_chair: bounds
# Saving to 4_chair: bounds_obj
# Saving to 4_chair: scale_factor
# Saving to 4_chair: center_for_translation
# Saving to 5_window: class
# Saving to 5_window: pts_inside
# Saving to 5_window: env_outside_pts
# Saving to 5_window: pts_on_env
# Saving to 5_window: pts_on_env_dists
# Saving to 5_window: env_outside_pts_dists
# Saving to 5_window: outside_points_dists
# Saving to 5_window: outside_points
# Saving to 5_window: control_points
# Saving to 5_window: control_points_on_env
# Saving to 5_window: control_points_env
# Saving to 5_window: control_points_interface
# Saving to 5_window: original
# Saving to 5_window: interface_pts
# Saving to 5_window: interface_normals
# Saving to 5_window: bounds
# Saving to 5_window: bounds_obj
# Saving to 5_window: scale_factor
# Saving to 5_window: center_for_translation
# Saving to 6_table: class
# Saving to 6_table: pts_inside
# Saving to 6_table: env_outside_pts
# Saving to 6_table: pts_on_env
# Saving to 6_table: pts_on_env_dists
# Saving to 6_table: env_outside_pts_dists
# Saving to 6_table: outside_points_dists
# Saving to 6_table: outside_points
# Saving to 6_table: control_points
# Saving to 6_table: control_points_on_env
# Saving to 6_table: control_points_env
# Saving to 6_table: control_points_interface
# Saving to 6_table: original
# Saving to 6_table: interface_pts
# Saving to 6_table: interface_normals
# Saving to 6_table: bounds
# Saving to 6_table: bounds_obj
# Saving to 6_table: scale_factor
# Saving to 6_table: center_for_translation
# Saving to 7_chair: class
# Saving to 7_chair: pts_inside
# Saving to 7_chair: env_outside_pts
# Saving to 7_chair: pts_on_env
# Saving to 7_chair: pts_on_env_dists
# Saving to 7_chair: env_outside_pts_dists
# Saving to 7_chair: outside_points_dists
# Saving to 7_chair: outside_points
# Saving to 7_chair: control_points
# Saving to 7_chair: control_points_on_env
# Saving to 7_chair: control_points_env
# Saving to 7_chair: control_points_interface
# Saving to 7_chair: original
# Saving to 7_chair: interface_pts
# Saving to 7_chair: interface_normals
# Saving to 7_chair: bounds
# Saving to 7_chair: bounds_obj
# Saving to 7_chair: scale_factor
# Saving to 7_chair: center_for_translation
# Saving to 8_ceiling: class
# Saving to 8_ceiling: pts_inside
# Saving to 8_ceiling: env_outside_pts
# Saving to 8_ceiling: pts_on_env
# Saving to 8_ceiling: pts_on_env_dists
# Saving to 8_ceiling: env_outside_pts_dists
# Saving to 8_ceiling: outside_points_dists
# Saving to 8_ceiling: outside_points
# Saving to 8_ceiling: control_points
# Saving to 8_ceiling: control_points_on_env
# Saving to 8_ceiling: control_points_env
# Saving to 8_ceiling: control_points_interface
# Saving to 8_ceiling: original
# Saving to 8_ceiling: interface_pts
# Saving to 8_ceiling: interface_normals
# Saving to 8_ceiling: bounds
# Saving to 8_ceiling: bounds_obj
# Saving to 8_ceiling: scale_factor
# Saving to 8_ceiling: center_for_translation
# Saving to 9_floor: class
# Saving to 9_floor: pts_inside
# Saving to 9_floor: env_outside_pts
# Saving to 9_floor: pts_on_env
# Saving to 9_floor: pts_on_env_dists
# Saving to 9_floor: env_outside_pts_dists
# Saving to 9_floor: outside_points_dists
# Saving to 9_floor: outside_points
# Saving to 9_floor: control_points
# Saving to 9_floor: control_points_on_env
# Saving to 9_floor: control_points_env
# Saving to 9_floor: control_points_interface
# Saving to 9_floor: original
# Saving to 9_floor: interface_pts
# Saving to 9_floor: interface_normals
# Saving to 9_floor: bounds
# Saving to 9_floor: bounds_obj
# Saving to 9_floor: scale_factor
# Saving to 9_floor: center_for_translation

# %%
import k3d
import numpy as np
import os

# Configuration
room_name = "room_0"  # Change as needed
segment_floor = True  # Set to False if needed
suffix = "_objects" if segment_floor else "_single"
name = room_name + suffix
diff_plots = False
point_size = 0.01
opacity = 0.9

base_path = os.path.join(
    "/scratch/rhm4nj/cral/cral-ginn/ginn/myvis/data_gen",
    "replica",
    name
)

# Color mapping (reuse from your previous code)
colors = {
    "original": 0xff0000,               # Red 0xff0000,       
    # "pts_inside": 0x00ff00,           # Green
    "interface_pts": 0x0000ff,        # Blue
    # "env_outside_pts": 0xff00ff,      # Yellow 0xffff00
    # "pts_on_env": 0xff00ff,           # Magenta
    # "outside_points": 0x00ffff,       # Cyan
    # "control_points": 0x808080,       # Gray
    # "control_points_on_env": 0x800080,# Orange 0xFFA500
    # "control_points_env": 0x800080,   # Purple
    # "control_points_interface": 0x008000 # Dark Green
}

# Helper to make a fresh plot with your camera preset
def make_plot():
    p = k3d.plot(camera_auto_fit=False, camera_mode='orbit')
    p.grid_visible = False
    # stool
    # p.camera = [2.8694741735495253, -0.8154392051170339, -1.1483259553430802, 1.8214549846928196, 0.5985451072664797, -1.1811511610445724, -0.2670660735979046, 0.32397051412119715, 0.9075895648987121]
    # sofa
    # p.camera = [7.190913913528872, 0.5330256030138187, -0.2471652467605272, 3.82949120603049, 2.81767514400493, -1.1671050844531397, -0.2670660735979046, 0.32397051412119715, 0.9075895648987121]
    # room
    p.camera = [9.363147453713152, -4.065776420196011, 6.964163674560844, 4.267417829437804, 2.1610196253176377, -1.7561941660844533, -0.2670660735979046, 0.32397051412119715, 0.9075895648987121]
    return p

if diff_plots:
    # One plot per key in 'colors'
    plots = { key: make_plot() for key in colors }
else:
    # Single shared plot
    plots = { 'all': make_plot() }

print("Classes:", sorted(os.listdir(base_path)))
for folder in sorted(os.listdir(base_path)):
    folder_path = os.path.join(base_path, folder)
    # if not os.path.isdir(folder_path) or '0_wall' not in folder_path:
    #     continue
    if not os.path.isdir(folder_path) or 'ceiling' in folder_path:
        continue

    print(f"\nLoading {folder}...")
    for file in os.listdir(folder_path):
        if not file.endswith('.npy'):
            continue

        key = file[:-4]  # strip “.npy”
        color = colors.get(key, None)
        if color is None:
            continue

        data = np.load(os.path.join(folder_path, file))
        if data.ndim != 2 or data.shape[1] < 3:
            continue

        pts = data[:, :3]
        if diff_plots:
            plots[key] += k3d.points(pts, point_size=point_size, color=color, opacity=opacity)
        else:
            plots['all'] += k3d.points(pts, point_size=point_size, color=color)

        print(f"  Visualized {key}: {pts.shape}")

# Finally display
if diff_plots:
    for key, p in plots.items(): 
        print("Plot for:", key)
        p.display()

else:
    plots['all'].display()
# Out:
# Classes: ['0_wall', '10_table', '11_lamp', '12_ceiling', '13_floor', '1_lamp', '2_table', '3_table', '4_table', '5_stool', '6_chair', '7_sofa', '8_stool', '9_chair']
#
# Loading 0_wall...
#   Visualized original: (300000, 3)
#   Visualized interface_pts: (51072, 3)
#
# Loading 10_table...
#   Visualized original: (5285, 3)
#   Visualized interface_pts: (2492, 3)
#
# Loading 11_lamp...
#   Visualized interface_pts: (2302, 3)
#   Visualized original: (4322, 3)
#
# Loading 13_floor...
#   Visualized original: (186607, 3)
#   Visualized interface_pts: (104965, 3)
#
# Loading 1_lamp...
#   Visualized original: (4314, 3)
#   Visualized interface_pts: (2213, 3)
#
# Loading 2_table...
#   Visualized interface_pts: (1239, 3)
#   Visualized original: (3145, 3)
#
# Loading 3_table...
#   Visualized interface_pts: (885, 3)
#   Visualized original: (2176, 3)
#
# Loading 4_table...
#   Visualized original: (24694, 3)
#   Visualized interface_pts: (13347, 3)
#
# Loading 5_stool...
#   Visualized original: (6753, 3)
#   Visualized interface_pts: (4154, 3)
#
# Loading 6_chair...
#   Visualized interface_pts: (13670, 3)
#   Visualized original: (19216, 3)
#
# Loading 7_sofa...
#   Visualized interface_pts: (40623, 3)
#   Visualized original: (50921, 3)
#
# Loading 8_stool...
#   Visualized interface_pts: (4287, 3)
#   Visualized original: (6850, 3)
#
# Loading 9_chair...
#   Visualized original: (19504, 3)
#   Visualized interface_pts: (13431, 3)
# Output()

# %%
if diff_plots:
    for key, p in plots.items():
        print("Plot for:", key, p.camera)
else:
    print(plots['all'].camera)
# Out:
# [9.363147453713152, -4.065776420196011, 6.964163674560844, 4.267417829437804, 2.1610196253176377, -1.7561941660844533, -0.2670660735979046, 0.32397051412119715, 0.9075895648987121]

# %%
# Meshes!
import k3d
import numpy as np
import os
from skimage import measure

# Configuration
room_name = "room_0"  # Change as needed
segment_floor = True  # Set to False if needed
suffix = "_objects" if segment_floor else "_single"
name = room_name + suffix
diff_plots = True
point_size = 0.01
opacity = 0.9

# 2) define a grid
res     = 20
padding = 0.35

base_path = os.path.join(
    "/scratch/rhm4nj/cral/cral-ginn/ginn/myvis/data_gen",
    "replica",
    name
)

# Color mapping (reuse from your previous code)
colors = {
    # "original": 0xff0000,               # Red 0xff0000,       
    # "pts_inside": 0x00ff00,           # Green
    "interface_pts": 0xff0000,        # Blue 0x0000ff
    # "env_outside_pts": 0xff00ff,      # Yellow 0xffff00
    # "pts_on_env": 0xff00ff,           # Magenta
    # "outside_points": 0x00ffff,       # Cyan
    # "control_points": 0x808080,       # Gray
    # "control_points_on_env": 0x800080,# Orange 0xFFA500
    # "control_points_env": 0x800080,   # Purple
    # "control_points_interface": 0x008000 # Dark Green
}

# Helper to make a fresh plot with your camera preset
def make_plot():
    p = k3d.plot(camera_auto_fit=False, camera_mode='orbit')
    p.grid_visible = False
    # stool
    # p.camera = [2.8694741735495253, -0.8154392051170339, -1.1483259553430802, 1.8214549846928196, 0.5985451072664797, -1.1811511610445724, -0.2670660735979046, 0.32397051412119715, 0.9075895648987121]
    # sofa
    p.camera = [7.190913913528872, 0.5330256030138187, -0.2471652467605272, 3.82949120603049, 2.81767514400493, -1.1671050844531397, -0.2670660735979046, 0.32397051412119715, 0.9075895648987121]
    # room
    # p.camera = [9.363147453713152, -4.065776420196011, 6.964163674560844, 4.267417829437804, 2.1610196253176377, -1.7561941660844533, -0.2670660735979046, 0.32397051412119715, 0.9075895648987121]
    return p


plots = { key: make_plot() for key in colors }

print("Classes:", sorted(os.listdir(base_path)))
for folder in sorted(os.listdir(base_path)):
    folder_path = os.path.join(base_path, folder)
    # if not os.path.isdir(folder_path) or '0_wall' not in folder_path:
    #     continue
    if not os.path.isdir(folder_path) or '6_chair' not in folder_path:
        continue

    print(f"\nLoading {folder}...")
    for file in os.listdir(folder_path):
        if not file.endswith('.npy'):
            continue

        key = file[:-4]  # strip “.npy”
        color = colors.get(key, None)
        if color is None:
            continue

        data = np.load(os.path.join(folder_path, file))
        if data.ndim != 2 or data.shape[1] < 3:
            continue

        pts = data[:, :3]
        # plots[key] += k3d.points(pts, point_size=point_size, color=color, opacity=opacity)

        mins    = pts.min(axis=0) - padding
        maxs    = pts.max(axis=0) + padding

        # grid coordinates
        xs = np.linspace(mins[0], maxs[0], res)
        ys = np.linspace(mins[1], maxs[1], res)
        zs = np.linspace(mins[2], maxs[2], res)

        # 3) voxelize via a histogram → occupancy field
        H, edges = np.histogramdd(pts, bins=[xs, ys, zs])
        voxel = (H > 0).astype(np.uint8)

        # 4) run marching cubes at iso‐level 0.5
        verts, faces, normals, values = measure.marching_cubes(
            volume=voxel,
            level=0.5,
            spacing=(xs[1]-xs[0], ys[1]-ys[0], zs[1]-zs[0])
        )

        verts += mins  # because marching_cubes with spacing still starts at 0
        mesh = k3d.mesh(
            vertices=verts.astype(np.float32),
            indices=faces.astype(np.uint32),
            color=color,
            opacity=1
        )

        plots[key] += mesh

        print(f"Visualized {key}: {pts.shape}")


for key, p in plots.items(): 
    print("Plot for:", key)
    p.display()
# Out:
# Classes: ['0_wall', '10_table', '11_lamp', '12_ceiling', '13_floor', '1_lamp', '2_table', '3_table', '4_table', '5_stool', '6_chair', '7_sofa', '8_stool', '9_chair']
#
# Loading 6_chair...
# Visualized interface_pts: (13670, 3)
# Plot for: interface_pts
# Output()

# %%
import os
import numpy as np
import k3d
from k3d.colormaps import matplotlib_color_maps

# parent directory containing one sub‐folder per object
# Configuration
room_name = "room_0"  # Change as needed
segment_floor = False  # Set to False if needed
suffix = "_objects" if segment_floor else "_single"
name = room_name + suffix

BASE_DIR = os.path.join(
    "/scratch/rhm4nj/cral/cral-ginn/ginn/myvis/data_gen",
    "replica",
    name
)

env_pts_all  = []
env_dists_all = []
int_all     = []

for obj_name in os.listdir(BASE_DIR):
    obj_dir = os.path.join(BASE_DIR, obj_name)
    if not os.path.isdir(obj_dir):
        continue

    # skip anything that isn't a wall
    cls = np.load(os.path.join(obj_dir, 'class.npy'), allow_pickle=True)
    # if it was saved as a 0‐d array of bytes
    if isinstance(cls, np.ndarray):
        cls = cls.item()
    if cls != 'wall':
        continue

    # load all four arrays we care about
    env_outside_pts       = np.load(os.path.join(obj_dir, 'env_outside_pts.npy'))
    env_outside_pts_dists = np.load(os.path.join(obj_dir, 'env_outside_pts_dists.npy'))
    on_env_pts            = np.load(os.path.join(obj_dir, 'pts_on_env.npy'))
    on_env_pts_dists      = np.load(os.path.join(obj_dir, 'pts_on_env_dists.npy'))
    interface_pts         = np.load(os.path.join(obj_dir, 'interface_pts.npy'))

    # accumulate
    env_pts_all.append(env_outside_pts)
    env_dists_all.append(env_outside_pts_dists)

    env_pts_all.append(on_env_pts)
    env_dists_all.append(on_env_pts_dists)

    int_all.append(interface_pts)

# now stack
if env_pts_all and env_dists_all and int_all:
    all_pts  = np.vstack(env_pts_all).astype(np.float32)
    all_dists= np.concatenate(env_dists_all).astype(np.float32)
    int_all  = np.vstack(int_all).astype(np.float32)

    for d in env_dists_all:
        print("min env_dists_all", d.min())
        print("max env_dists_all", d.max())
        print("mean env_dists_all", d.mean())
        print(d)

    plot = k3d.plot()
    plot += k3d.points(
        all_pts,
        attribute=all_dists,
        point_size=0.05,
        color_map=matplotlib_color_maps.Inferno
    )
    plot += k3d.points(
        int_all,
        point_size=0.05,
        color=0x0000ff
    )
    plot.display()
else:
    print("No envelope or on‐env points found.")
# Out:
# min env_dists_all 0.11405750941978292
# max env_dists_all 2.1802668774291813
# mean env_dists_all 0.7156217344811004
# [0.52148752 0.60692479 1.1182893  ... 1.79264334 1.15162009 1.25623083]
# min env_dists_all 0.07643154236449852
# max env_dists_all 0.1933685763978672
# mean env_dists_all 0.12458255735815131
# [0.12919837 0.11463773 0.13405333 ... 0.14038942 0.09053917 0.16536346]
# Output()
